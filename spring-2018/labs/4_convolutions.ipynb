# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import cPickle as pickle
import numpy as np
import tensorflow as tf

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print 'Training set', train_dataset.shape, train_labels.shape
  print 'Validation set', valid_dataset.shape, valid_labels.shape
  print 'Test set', test_dataset.shape, test_labels.shape
# Out:
# Training set (400000, 28, 28) (400000,)
# Validation set (30000, 28, 28) (30000,)
# Test set (18724, 28, 28) (18724,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print 'Training set', train_dataset.shape, train_labels.shape
print 'Validation set', valid_dataset.shape, valid_labels.shape
print 'Test set', test_dataset.shape, test_labels.shape
# Out:
# Training set (400000, 28, 28, 1) (400000, 10)
# Validation set (30000, 28, 28, 1) (30000, 10)
# Test set (18724, 28, 28, 1) (18724, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print "Minibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
  print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
# Minibatch loss at step 0 : 3.4189
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.8%
# Minibatch loss at step 50 : 1.42877
# Minibatch accuracy: 37.5%
# Validation accuracy: 61.4%
# Minibatch loss at step 100 : 0.862793
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.6%
# Minibatch loss at step 150 : 1.35413
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.0%
# Minibatch loss at step 200 : 1.2206
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.9%
# Minibatch loss at step 250 : 0.440559
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 300 : 0.689094
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.9%
# Minibatch loss at step 350 : 1.02358
# Minibatch accuracy: 56.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 400 : 0.544306
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 450 : 0.809441
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 500 : 0.744732
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.8%
# Minibatch loss at step 550 : 0.272188
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 600 : 0.308498
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 650 : 0.320159
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 700 : 0.838302
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 750 : 1.44989
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 800 : 0.745544
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 850 : 0.954671
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 900 : 0.978859
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 950 : 0.825197
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 1000 : 0.209976
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.0%
# Test accuracy: 89.6%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print "Minibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
  print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
# Minibatch loss at step 0 : 3.76722
# Minibatch accuracy: 0.0%
# Validation accuracy: 9.8%
# Minibatch loss at step 50 : 2.28527
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.3%
# Minibatch loss at step 100 : 2.16422
# Minibatch accuracy: 12.5%
# Validation accuracy: 14.3%
# Minibatch loss at step 150 : 1.77017
# Minibatch accuracy: 56.2%
# Validation accuracy: 45.0%
# Minibatch loss at step 200 : 1.6221
# Minibatch accuracy: 56.2%
# Validation accuracy: 54.2%
# Minibatch loss at step 250 : 0.811453
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.0%
# Minibatch loss at step 300 : 0.779612
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.7%
# Minibatch loss at step 350 : 1.00978
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 400 : 0.4442
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 450 : 0.878873
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 500 : 1.03681
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 550 : 0.252833
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.1%
# Minibatch loss at step 600 : 0.409035
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 650 : 0.186281
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 700 : 0.698439
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 750 : 1.35503
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 800 : 0.721285
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 850 : 0.872928
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 900 : 0.754433
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 950 : 0.813048
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 1000 : 0.13444
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.7%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 128
num_steps = 3001
reporting_epoch = 100

patch_size = 5
depth = 16
num_hidden = 64
beta = 5e-3 

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  keep_prob = tf.placeholder(tf.float32) #init dropout
    
  # Model.
  def model(data, use_dropout=False):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    if use_dropout:
        reshape = tf.nn.dropout(reshape, keep_prob)
    
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    if use_dropout:
        hidden = tf.nn.dropout(hidden, keep_prob)
    
    output = tf.matmul(hidden, layer4_weights) + layer4_biases
    
    return output
  
  # Training computation.
  logits = model(tf_train_dataset, use_dropout=True)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # L2 regularization for the fully connected parameters.
  regularizers = (tf.nn.l2_loss(layer1_weights) + tf.nn.l2_loss(layer1_biases)
                + tf.nn.l2_loss(layer2_weights) + tf.nn.l2_loss(layer2_biases)
                + tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer3_biases)
                + tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(layer4_biases))
  # Add the regularization term to the loss.
  loss += beta * regularizers

  # Setup learning rate with decay
  global_step = tf.Variable(0)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.05, step, num_steps, 0.98)

  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : .95}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % reporting_epoch == 0):
      print "Minibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
  print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
# Minibatch loss at step 0 : 4.23907
# Minibatch accuracy: 10.2%
# Validation accuracy: 10.5%
# Minibatch loss at step 100 : 2.22211
# Minibatch accuracy: 76.6%
# Validation accuracy: 76.0%
# Minibatch loss at step 200 : 1.99172
# Minibatch accuracy: 76.6%
# Validation accuracy: 81.0%
# Minibatch loss at step 300 : 1.68692
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 400 : 1.64003
# Minibatch accuracy: 82.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 500 : 1.55615
# Minibatch accuracy: 86.7%
# Validation accuracy: 84.1%
# Minibatch loss at step 600 : 1.73375
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 700 : 1.62033
# Minibatch accuracy: 80.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 800 : 1.32491
# Minibatch accuracy: 89.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 900 : 1.4526
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 1000 : 1.34075
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.6%
# Minibatch loss at step 1100 : 1.22038
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.1%
# Minibatch loss at step 1200 : 1.2972
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 1300 : 1.28145
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.4%
# Minibatch loss at step 1400 : 1.26036
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 1500 : 1.22982
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 1600 : 1.22972
# Minibatch accuracy: 83.6%
# Validation accuracy: 86.8%
# Minibatch loss at step 1700 : 0.9563
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 1800 : 0.920683
# Minibatch accuracy: 93.0%
# Validation accuracy: 87.4%
# Minibatch loss at step 1900 : 1.00283
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 2000 : 1.1495
# Minibatch accuracy: 78.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 2100 : 1.07695
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 2200 : 1.19273
# Minibatch accuracy: 82.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 2300 : 0.896524
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 2400 : 0.969486
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 2500 : 1.12228
# Minibatch accuracy: 78.9%
# Validation accuracy: 87.9%
# Minibatch loss at step 2600 : 0.7938
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.2%
# Minibatch loss at step 2700 : 0.928106
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.3%
# Minibatch loss at step 2800 : 0.75092
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 2900 : 0.889263
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 3000 : 0.835643
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.3%
# Test accuracy: 93.8%

# %% [markdown]
# LeNet 5 architecture

# %%
batch_size = 128
num_steps = 33001
reporting_epoch = 500

patch_size = 5

depth = 16
depth2 = 32

num_hidden = 64

beta = 5e-3 

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 4 * image_size / 4 * depth2, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  keep_prob = tf.placeholder(tf.float32) #init dropout
    
  # Model.
  def model(data, use_dropout=False):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    if use_dropout:
        reshape = tf.nn.dropout(reshape, keep_prob)
    
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    if use_dropout:
        hidden = tf.nn.dropout(hidden, keep_prob)
    
    output = tf.matmul(hidden, layer4_weights) + layer4_biases
    
    return output
  
  # Training computation.
  logits = model(tf_train_dataset, use_dropout=True)
  loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # L2 regularization for the fully connected parameters.
  regularizers = (tf.nn.l2_loss(layer1_weights) + tf.nn.l2_loss(layer1_biases)
                + tf.nn.l2_loss(layer2_weights) + tf.nn.l2_loss(layer2_biases)
                + tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer3_biases)
                + tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(layer4_biases))
  # Add the regularization term to the loss.
  loss += beta * regularizers

  # Setup learning rate with decay
  global_step = tf.Variable(0)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.05, step, num_steps, 0.96)

  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  #optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob : .7}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % reporting_epoch == 0):
      print "Minibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
  print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
# Minibatch loss at step 0 : 8.17711
# Minibatch accuracy: 7.8%
# Validation accuracy: 10.1%
# Minibatch loss at step 500 : 2.6098
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 1000 : 2.16528
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 1500 : 1.85515
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 2000 : 1.60014
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 2500 : 1.50128
# Minibatch accuracy: 79.7%
# Validation accuracy: 87.4%
# Minibatch loss at step 3000 : 1.16305
# Minibatch accuracy: 82.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 3500 : 0.983578
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.2%
# Minibatch loss at step 4000 : 0.902582
# Minibatch accuracy: 83.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 4500 : 0.863595
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.6%
# Minibatch loss at step 5000 : 0.781651
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 5500 : 0.622874
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.9%
# Minibatch loss at step 6000 : 0.735806
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 6500 : 0.525761
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 7000 : 0.453105
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.4%
# Minibatch loss at step 7500 : 0.534479
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 8000 : 0.603623
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.6%
# Minibatch loss at step 8500 : 0.534786
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.6%
# Minibatch loss at step 9000 : 0.641386
# Minibatch accuracy: 82.0%
# Validation accuracy: 89.6%
# Minibatch loss at step 9500 : 0.595993
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 10000 : 0.613434
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 10500 : 0.432984
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 11000 : 0.467292
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 11500 : 0.418641
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 12000 : 0.416441
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.8%
# Minibatch loss at step 12500 : 0.511894
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.0%
# Minibatch loss at step 13000 : 0.56126
# Minibatch accuracy: 83.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 13500 : 0.382309
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 14000 : 0.605375
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.0%
# Minibatch loss at step 14500 : 0.503995
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Minibatch loss at step 15000 : 0.509446
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.0%
# Minibatch loss at step 15500 : 0.439899
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
# Minibatch loss at step 16000 : 0.441424
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 16500 : 0.46311
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 17000 : 0.563805
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 17500 : 0.411686
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 18000 : 0.343384
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 18500 : 0.374937
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 19000 : 0.40031
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 19500 : 0.523158
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# Minibatch loss at step 20000 : 0.595941
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 20500 : 0.398608
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.1%
# Minibatch loss at step 21000 : 0.454895
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 21500 : 0.56999
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 22000 : 0.424541
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 22500 : 0.582435
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.0%
# Minibatch loss at step 23000 : 0.513567
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.1%
# Minibatch loss at step 23500 : 0.46921
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.9%
# Minibatch loss at step 24000 : 0.463714
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 24500 : 0.672636
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 25000 : 0.439411
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 25500 : 0.507263
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 26000 : 0.48191
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Minibatch loss at step 26500 : 0.638366
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 27000 : 0.458378
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 27500 : 0.447543
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 28000 : 0.638133
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.0%
# Minibatch loss at step 28500 : 0.521648
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.3%
# Minibatch loss at step 29000 : 0.641654
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 29500 : 0.464846
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.1%
# Minibatch loss at step 30000 : 0.460922
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 30500 : 0.507602
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 31000 : 0.478009
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 31500 : 0.667604
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.0%
# Minibatch loss at step 32000 : 0.453714
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 32500 : 0.492682
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 33000 : 0.639451
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.0%
# Test accuracy: 95.1%
